# %% [markdown]
# # XQuantiPy
#
# This notebook demonstrates the usage of XQuantiPy module

# %% [markdown]
# ### 1. Working with individual stocks

# %% [markdown]
# This section demonstrates the usage of XQuantiPy module when working with individual stocks.

# %%
# Import the required module
# !pip install nbformat
from xquantipy.stocks.ticker import Ticker
# Out:
# Requirement already satisfied: nbformat in /opt/anaconda3/envs/xquantipy/lib/python3.9/site-packages (5.9.2)
# Requirement already satisfied: fastjsonschema in /opt/anaconda3/envs/xquantipy/lib/python3.9/site-packages (from nbformat) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /opt/anaconda3/envs/xquantipy/lib/python3.9/site-packages (from nbformat) (4.21.1)
# Requirement already satisfied: jupyter-core in /opt/anaconda3/envs/xquantipy/lib/python3.9/site-packages (from nbformat) (5.5.0)
# Requirement already satisfied: traitlets>=5.1 in /opt/anaconda3/envs/xquantipy/lib/python3.9/site-packages (from nbformat) (5.14.1)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/xquantipy/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/xquantipy/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/xquantipy/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/xquantipy/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/xquantipy/lib/python3.9/site-packages (from jupyter-core->nbformat) (4.2.0)

# %%
# Getting individual stock object
AAPL = Ticker('AAPL', '1Y')
AAPL.data
# Out:
# [*********************100%%**********************]  1 of 1 completed
# https://query2.finance.yahoo.com/v7/finance/options/AAPL
# Error fetching fundamental data: 401
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2023-02-14  152.119995  153.770004  150.860001  153.199997  152.386597
# 1   2023-02-15  153.110001  155.500000  152.880005  155.330002  154.505310
# 2   2023-02-16  153.509995  156.330002  153.350006  153.710007  152.893906
# 3   2023-02-17  152.350006  153.000000  150.850006  152.550003  151.740067
# 4   2023-02-21  150.199997  151.300003  148.410004  148.479996  147.691666
# ..         ...         ...         ...         ...         ...         ...
# 246 2024-02-07  190.639999  191.050003  188.610001  189.410004  189.168625
# 247 2024-02-08  189.389999  189.539993  187.350006  188.320007  188.080017
# 248 2024-02-09  188.649994  189.990005  188.000000  188.850006  188.850006
# 249 2024-02-12  188.419998  188.669998  186.789993  187.149994  187.149994
# 250 2024-02-13  185.770004  186.210007  183.512802  185.039993  185.039993
#
#        Volume  daily_return  cum_return
# 0    61707600           NaN         NaN
# 1    65573800      0.013904    0.013904
# 2    68167900     -0.010429    0.003329
# 3    59144100     -0.007547   -0.004243
# 4    58867200     -0.026680   -0.030809
# ..        ...           ...         ...
# 246  53439000      0.000581    0.241373
# 247  40962000     -0.005755    0.234229
# 248  45099900      0.004094    0.239282
# 249  41781900     -0.009002    0.228126
# 250  54080860     -0.011274    0.214280
#
# [251 rows x 9 columns]

# %%
AAPL.get_adj_close()
# Out:
#           Date        AAPL
# 0   2023-02-14  152.386597
# 1   2023-02-15  154.505310
# 2   2023-02-16  152.893906
# 3   2023-02-17  151.740067
# 4   2023-02-21  147.691666
# ..         ...         ...
# 246 2024-02-07  189.168625
# 247 2024-02-08  188.080017
# 248 2024-02-09  188.850006
# 249 2024-02-12  187.149994
# 250 2024-02-13  185.039993
#
# [251 rows x 2 columns]

# %%
AAPL.get_beta()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 1.11

# %%
AAPL.get_alpha()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# -0.006598174833528758

# %%
AAPL.show_adj_close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/envs/xquantipy/lib/python3.9/site-packages/IPython/core/formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File /opt/anaconda3/envs/xquantipy/lib/python3.9/site-packages/plotly/basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File /opt/anaconda3/envs/xquantipy/lib/python3.9/site-packages/plotly/io/_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'mode': 'lines',
#               'name': 'Closing Price',
#               'type': 'scatter',
#               'x': array([datetime.datetime(2023, 2, 14, 0, 0),
#                           datetime.datetime(2023, 2, 15, 0, 0),
#                           datetime.datetime(2023, 2, 16, 0, 0), ...,
#                           datetime.datetime(2024, 2, 9, 0, 0),
#                           datetime.datetime(2024, 2, 12, 0, 0),
#                           datetime.datetime(2024, 2, 13, 0, 0)], dtype=object),
#               'y': array([152.38659668, 154.50531006, 152.89390564, ..., 188.8500061 ,
#                           187.1499939 , 185.03999329])}],
#     'layout': {'showlegend': True,
#                'template': '...',
#                'title': {'text': 'AAPL Stock Price'},
#                'xaxis': {'title': {'text': 'Date'}},
#                'yaxis': {'title': {'text': 'Adj Close AAPL'}}}
# })
